# %% [markdown]
# Import necessary modules for cleaning and visualitation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Import water cosumption database from the first link provided from Aigües de Barcelona

# %%
data = pd.read_csv("export.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Get some information regarding the database

# %%
data.shape
# Out:
# (365, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    365 non-null    object
#  1   tavg    365 non-null    float64
#  2   tmin    365 non-null    float64
#  3   tmax    365 non-null    float64
#  4   prcp    365 non-null    float64
#  5   snow    0 non-null      float64
#  6   wdir    0 non-null      float64
#  7   wspd    365 non-null    float64
#  8   wpgt    365 non-null    float64
#  9   pres    365 non-null    float64
#  10  tsun    354 non-null    float64
# dtypes: float64(10), object(1)
# memory usage: 31.5+ KB

# %%
data.head()
# Out:
#                   date  tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt  \
# 0  2023-01-01 00:00:00  11.0   8.6  15.9   0.0   NaN   NaN  10.0  27.8
# 1  2023-01-02 00:00:00  10.7   7.0  15.0   0.0   NaN   NaN  14.1  31.5
# 2  2023-01-03 00:00:00  12.4   8.2  17.6   0.0   NaN   NaN  12.1  24.1
# 3  2023-01-04 00:00:00  10.3   7.5  16.1   0.0   NaN   NaN  14.8  29.6
# 4  2023-01-05 00:00:00   9.5   5.7  15.6   0.0   NaN   NaN  15.6  31.5
#
#      pres   tsun
# 0  1025.8  267.0
# 1  1024.6  178.0
# 2  1029.2  230.0
# 3  1032.6  451.0
# 4  1028.8  480.0

# %%
data.describe(include='all')
# Out:
#                        date        tavg        tmin        tmax        prcp  \
# count                   365  365.000000  365.000000  365.000000  365.000000
# unique                  365         NaN         NaN         NaN         NaN
# top     2023-12-31 00:00:00         NaN         NaN         NaN         NaN
# freq                      1         NaN         NaN         NaN         NaN
# mean                    NaN   17.377808   13.994521   21.686301    0.752055
# std                     NaN    6.309558    6.831393    5.921778    4.003553
# min                     NaN    4.600000   -0.800000    6.200000    0.000000
# 25%                     NaN   12.300000    8.500000   16.600000    0.000000
# 50%                     NaN   17.000000   14.000000   21.600000    0.000000
# 75%                     NaN   22.900000   19.800000   26.800000    0.000000
# max                     NaN   30.200000   26.800000   35.100000   53.600000
#
#         snow  wdir        wspd        wpgt         pres        tsun
# count    0.0   0.0  365.000000  365.000000   365.000000  354.000000
# unique   NaN   NaN         NaN         NaN          NaN         NaN
# top      NaN   NaN         NaN         NaN          NaN         NaN
# freq     NaN   NaN         NaN         NaN          NaN         NaN
# mean     NaN   NaN   14.873425   31.562192  1016.938356  442.158192
# std      NaN   NaN    4.505727    7.988095     6.747373  186.257393
# min      NaN   NaN    5.900000   18.500000   992.200000    3.000000
# 25%      NaN   NaN   12.100000   25.900000  1013.500000  315.250000
# 50%      NaN   NaN   14.200000   29.600000  1016.300000  448.500000
# 75%      NaN   NaN   16.600000   35.200000  1020.200000  592.750000
# max      NaN   NaN   39.800000   68.500000  1037.800000  825.000000
