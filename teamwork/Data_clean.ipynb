# %% [markdown]
# #Dataclean

# %% [markdown]
# Los inputs para el primer data_clean son:
# - https://www.abdatachallenge.cat/
#
# De la primera datashet, del consumo por L/día de agua, en base a los distritos.

# %% [markdown]
# Import necessary modules for cleaning and visualitation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Import water cosumption database from the first link provided from Aigües de Barcelona

# %%
data = pd.read_parquet("./data/01_table.parquet")

# %% [markdown]
# Get some information regarding the database

# %%
data.shape
# Out:
# (963419, 7)

# %%
data.head()
# Out:
#   Secció censal/Sección censal/Census section Districte/Distrito/District  \
# 0                                   801901001                           1
# 1                                   801901001                           1
# 2                                   801901001                           1
# 3                                   801901001                           1
# 4                                   801901001                           1
#
#   Municipi/Municipio/Municipality Data/Fecha/Date  \
# 0                       BARCELONA      2023-01-01
# 1                       BARCELONA      2023-01-01
# 2                       BARCELONA      2023-01-01
# 3                       BARCELONA      2023-01-02
# 4                       BARCELONA      2023-01-02
#
#                          Ús/Uso/Use  \
# 0    Comercial/Comercial/Commercial
# 1       Domèstic/Doméstico/Domestic
# 2  Industrial/Industrial/Industrial
# 3    Comercial/Comercial/Commercial
# 4       Domèstic/Doméstico/Domestic
#
#    Nombre de comptadors/Número de contadores/Number of meters  \
# 0                                                 64
# 1                                                395
# 2                                                 20
# 3                                                 64
# 4                                                395
#
#    Consum acumulat (L/dia)/Consumo acumulado (L/día)/Accumulated consumption (L/day)
# 0                                              14258
# 1                                              11089
# 2                                             490360
# 3                                               6780
# 4                                              11571

# %%
data.tail()
# Out:
#        Secció censal/Sección censal/Census section  \
# 963414                                        None
# 963415                                        None
# 963416                                        None
# 963417                                        None
# 963418                                        None
#
#        Districte/Distrito/District Municipi/Municipio/Municipality  \
# 963414                        None                       BARCELONA
# 963415                        None                       BARCELONA
# 963416                        None                       BARCELONA
# 963417                        None                       BARCELONA
# 963418                        None                       BARCELONA
#
#        Data/Fecha/Date                        Ús/Uso/Use  \
# 963414      2023-12-30       Domèstic/Doméstico/Domestic
# 963415      2023-12-30  Industrial/Industrial/Industrial
# 963416      2023-12-31    Comercial/Comercial/Commercial
# 963417      2023-12-31       Domèstic/Doméstico/Domestic
# 963418      2023-12-31  Industrial/Industrial/Industrial
#
#         Nombre de comptadors/Número de contadores/Number of meters  \
# 963414                                               2082
# 963415                                                 87
# 963416                                                237
# 963417                                               2082
# 963418                                                 87
#
#         Consum acumulat (L/dia)/Consumo acumulado (L/día)/Accumulated consumption (L/day)
# 963414                                              48293
# 963415                                             255366
# 963416                                              20749
# 963417                                              53443
# 963418                                             230242

# %%
data.describe(include='all')
# Out:
#        Secció censal/Sección censal/Census section  \
# count                                       962324
# unique                                        1075
# top                                      801901001
# freq                                          1095
# mean                                           NaN
# std                                            NaN
# min                                            NaN
# 25%                                            NaN
# 50%                                            NaN
# 75%                                            NaN
# max                                            NaN
#
#        Districte/Distrito/District Municipi/Municipio/Municipality  \
# count                       962324                          963419
# unique                          13                               1
# top                              2                       BARCELONA
# freq                        162450                          963419
# mean                           NaN                             NaN
# std                            NaN                             NaN
# min                            NaN                             NaN
# 25%                            NaN                             NaN
# 50%                            NaN                             NaN
# 75%                            NaN                             NaN
# max                            NaN                             NaN
#
#        Data/Fecha/Date                   Ús/Uso/Use  \
# count           963419                       963419
# unique             365                            3
# top         2023-12-31  Domèstic/Doméstico/Domestic
# freq              2680                       392307
# mean               NaN                          NaN
# std                NaN                          NaN
# min                NaN                          NaN
# 25%                NaN                          NaN
# 50%                NaN                          NaN
# 75%                NaN                          NaN
# max                NaN                          NaN
#
#         Nombre de comptadors/Número de contadores/Number of meters  \
# count                                       963419.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           252.194256
# std                                            283.118277
# min                                              2.000000
# 25%                                             25.000000
# 50%                                             70.000000
# 75%                                            493.000000
# max                                           2917.000000
#
#         Consum acumulat (L/dia)/Consumo acumulado (L/día)/Accumulated consumption (L/day)
# count                                        9.634190e+05
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                         2.374084e+04
# std                                          2.261520e+05
# min                                         -1.642869e+06
# 25%                                          3.832000e+03
# 50%                                          8.079000e+03
# 75%                                          1.503100e+04
# max                                          1.693004e+07

# %% [markdown]
# Rename the columns so we don´t have any errors with formatting

# %%
data.columns = ['Seccio_censal', 'Districte', 'Municipi', 'Data', 'Tipus_us', 'Numero_de_comptadors', 'Consum_litres_per_dia' ]

# %% [markdown]
# Una vez corregido los columns_names debido a posibles fallos con los espacios o caracteres especiales. Realizamos una primera comprobación de limpieza

# %% [markdown]
# Comprobamos valores nulos

# %%
data.isnull().sum()
# Out:
# Seccio_censal            1095
# Districte                1095
# Municipi                    0
# Data                        0
# Tipus_us                    0
# Numero_de_comptadors        0
# Consum_litres_per_dia       0
# dtype: int64

# %% [markdown]
# Con esto sabemos que las principales tablas que vamos a tener que limpiar son Seccio_cesal y Distrito.

# %% [markdown]
# Clean null values

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# Seccio_censal            0
# Districte                0
# Municipi                 0
# Data                     0
# Tipus_us                 0
# Numero_de_comptadors     0
# Consum_litres_per_dia    0
# dtype: int64

# %% [markdown]
# A primera vista parece corregido, pero investigando un poco más los valores con data.tail(), observamos que tiene valores nulos, pero que no los ha identificado debido a su tipo.

# %%
data.tail()
# Out:
#        Seccio_censal Districte   Municipi        Data  \
# 962319        <NULL>         >  BARCELONA  2023-12-30
# 962320        <NULL>         >  BARCELONA  2023-12-30
# 962321        <NULL>         >  BARCELONA  2023-12-31
# 962322        <NULL>         >  BARCELONA  2023-12-31
# 962323        <NULL>         >  BARCELONA  2023-12-31
#
#                                 Tipus_us  Numero_de_comptadors  \
# 962319       Domèstic/Doméstico/Domestic                  2917
# 962320  Industrial/Industrial/Industrial                   301
# 962321    Comercial/Comercial/Commercial                   345
# 962322       Domèstic/Doméstico/Domestic                  2917
# 962323  Industrial/Industrial/Industrial                   301
#
#         Consum_litres_per_dia
# 962319                  71934
# 962320                 417221
# 962321                  30746
# 962322                  80369
# 962323                 410164

# %% [markdown]
# Estos valores incorrectos se deben debido a que contienen caracteres especiales, que en la primera busqueda no ha identificado.

# %% [markdown]
# Convert columns to correct type

# %% [markdown]
# En data_cesal y en Districte los datos eran:
# - NULL
# - '< NULL >'
# - <

# %%
data['Seccio_censal'] = data['Seccio_censal'].replace(['<NULL>', '<N/A>', '<', 'NA'], np.nan).astype('Int64')

# %%
data.isnull().sum()
# Out:
# Seccio_censal            1095
# Districte                   0
# Municipi                    0
# Data                        0
# Tipus_us                    0
# Numero_de_comptadors        0
# Consum_litres_per_dia       0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Seccio_censal            0
# Districte                0
# Municipi                 0
# Data                     0
# Tipus_us                 0
# Numero_de_comptadors     0
# Consum_litres_per_dia    0
# dtype: int64

# %% [markdown]
# Comparamos los datos y hay que comparar cuantos se ha perdido, debido a que en nuestra data, el valor más importante es el codigo de Seccio_censal, no podremos sustituir los datos, asi que tendremos que eliminarlos

# %%
shape_org = 963419

new_shape = data.shape
print(f"shape original: {shape_org}, shape final: {new_shape}")
# Out:
# shape original: 963419, shape final: (961229, 7)

# %% [markdown]
# Hagamos otro estudio de los datos, examinemos con profundidad si nos queda algún valor imprevisto en Districte

# %%
data.tail()
# Out:
#         Seccio_censal Districte   Municipi        Data  \
# 961224      820506001        06  BARCELONA  2023-12-27
# 961225      820506001        06  BARCELONA  2023-12-28
# 961226      820506001        06  BARCELONA  2023-12-29
# 961227      820506001        06  BARCELONA  2023-12-30
# 961228      820506001        06  BARCELONA  2023-12-31
#
#                            Tipus_us  Numero_de_comptadors  \
# 961224  Domèstic/Doméstico/Domestic                    10
# 961225  Domèstic/Doméstico/Domestic                    10
# 961226  Domèstic/Doméstico/Domestic                    10
# 961227  Domèstic/Doméstico/Domestic                    10
# 961228  Domèstic/Doméstico/Domestic                    10
#
#         Consum_litres_per_dia
# 961224                   1252
# 961225                   1003
# 961226                   1336
# 961227                    742
# 961228                   1040

# %%
assert not data['Districte'].isin(['<NULL>', '<N/A>', '<', 'NA']).any(), \
    "Error: La columna 'Districte' todavía contiene valores no válidos ('<NULL>', '<N/A>', '<', 'NA')."

# %% [markdown]
# Comprobamos que todos los datos restantes sean correctos, lo comprobamos con un assert y nos encargamos de castear todos los datos correctamente, para poder operar con ellos, en un futuro

# %%
data['Districte'] = data['Districte'].astype('Int64')

# %%
data['Numero_de_comptadors'] = data['Numero_de_comptadors'].astype('Int64')

data.loc[:, 'Data'] = pd.to_datetime(data['Data'], errors='coerce')
data.loc[:, 'Seccio_censal'] = pd.to_numeric(data['Seccio_censal'], errors='coerce')
data.loc[:, 'Districte'] = pd.to_numeric(data['Districte'], errors='coerce')
data.loc[:, 'Numero_de_comptadors'] = pd.to_numeric(data['Numero_de_comptadors'], errors='coerce')
data.loc[:, 'Consum_litres_per_dia'] = pd.to_numeric(data['Consum_litres_per_dia'], errors='coerce')
data.loc[:, 'Municipi'] = data['Municipi'].astype(str)
data.loc[:, 'Tipus_us'] = data['Tipus_us'].astype(str)

# %% [markdown]
# The "tipus_us" column has values in 3 languages, put them in catalan

# %%
data['Tipus_us'] = data['Tipus_us'].str.split('/').str[-1].str.strip().str.lower()

# %% [markdown]
# Realizamos un comprobación de los datos

# %%
data.head()
data.tail()
# Out:
#         Seccio_censal  Districte   Municipi                 Data  Tipus_us  \
# 961224      820506001          6  BARCELONA  2023-12-27 00:00:00  domestic
# 961225      820506001          6  BARCELONA  2023-12-28 00:00:00  domestic
# 961226      820506001          6  BARCELONA  2023-12-29 00:00:00  domestic
# 961227      820506001          6  BARCELONA  2023-12-30 00:00:00  domestic
# 961228      820506001          6  BARCELONA  2023-12-31 00:00:00  domestic
#
#         Numero_de_comptadors  Consum_litres_per_dia
# 961224                    10                   1252
# 961225                    10                   1003
# 961226                    10                   1336
# 961227                    10                    742
# 961228                    10                   1040

# %% [markdown]
# Remove rows with negative or unrealistic consumption:

# %%
data = data[data['Consum_litres_per_dia'] > 0]

# %% [markdown]
# Remove duplicates

# %%
data = data.drop_duplicates()

# %% [markdown]
# Fix inconsistent categories

# %%
data['Municipi'] = data['Municipi'].str.strip().str.upper()
data['Tipus_us'] = data['Tipus_us'].str.strip().str.capitalize()

# %% [markdown]
# Check values have the right format

# %%
data.tail()
# Out:
#         Seccio_censal  Districte   Municipi                 Data  Tipus_us  \
# 961224      820506001          6  BARCELONA  2023-12-27 00:00:00  Domestic
# 961225      820506001          6  BARCELONA  2023-12-28 00:00:00  Domestic
# 961226      820506001          6  BARCELONA  2023-12-29 00:00:00  Domestic
# 961227      820506001          6  BARCELONA  2023-12-30 00:00:00  Domestic
# 961228      820506001          6  BARCELONA  2023-12-31 00:00:00  Domestic
#
#         Numero_de_comptadors  Consum_litres_per_dia
# 961224                    10                   1252
# 961225                    10                   1003
# 961226                    10                   1336
# 961227                    10                    742
# 961228                    10                   1040

# %% [markdown]
# Hagamos una comprobación final

# %%
eq_shape = 958504/963419 * 100
print(f"shape original: 963419, shape final: 958504, eq: {eq_shape}% de los datos")
# Out:
# shape original: 963419, shape final: 958504, eq: 99.48983775491246% de los datos

# %% [markdown]
# Representando que la perdida sobre el shape original es apenas inferior a 0.5%

# %% [markdown]
# Values have now the right format and null values are removed

# %% [markdown]
# Create multiple tables per Tipus_us and and Districte

# %%
import os

# %%
output_folder = "output_tables"
os.makedirs(output_folder, exist_ok=True)

# %%
tables = {}

for (district, tipus), group in data.groupby(['Districte', 'Tipus_us']):
    group = group.reset_index(drop=True)
    key = f"D{district}_{tipus}"
    tables[key] = group


for key, table in tables.items():
    safe_key = str(key).replace('/', '_').replace('\\', '_').replace(' ', '_')
    table.to_csv(os.path.join(output_folder, f"{safe_key}.csv"), index=False)

# %%
for key, table in tables.items():
    table['Data'] = pd.to_datetime(table['Data'], errors='coerce')
    table = table.sort_values('Data')  # sort by date

    plt.figure(figsize=(10,4))
    plt.plot(table['Data'], table['Consum_litres_per_dia'], marker='o', linestyle='-', markersize=4)
    plt.title(f"Daily Consumption over Time - {key}")
    plt.xlabel("Date")
    plt.ylabel("Consum litres per day")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
